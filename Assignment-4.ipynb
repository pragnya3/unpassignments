# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import statistics as st

# %% [markdown]
# **Problem-1**<br>
# In the "fmri" dataset, find the range of the "timepoint" point column using a boxplot.

# %%
data = sns.load_dataset('fmri')
data
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.boxplot(x='timepoint', data=data)

# %% [markdown]
# **Problem-2**<br>
# Construct a pie chart describing the distribution of subclasses in the column 'region'.

# %%
reg=data.groupby('region')['region'].count()

# %%
plt.pie(reg,labels=reg.index, autopct='%.2f%%')
plt.show()

# %% [markdown]
# **Problem-3**<br>
# In the diamonds dataset, fit a regression plot for price vs carat. (Use the appropriate order to fit the data properly)

# %%
diamond = sns.load_dataset('diamonds')
diamond
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.regplot(x='price', y='carat', data=diamond.sample(1000), order=5, marker='+')

# %% [markdown]
# **Problem-4**<br>
# Construct a bar plot of cut vs price and determine which variety of cut has the highest median price.(Note: Don't construct a barplot directly, first group by cut, then extract the median of price)

# %%
cut=diamond.groupby('cut')['cut'].count()
cut
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
g = np.median(cut.values)
g
# Out:
# 12082.0

# %%
sns.barplot(x=cut.index, y=cut.values, data=diamond);

# %% [markdown]
# **Problem-5**<br>
# In the penguins dataset, construct a violin plot of flipper length based on gender. Construct a boxen plot for the same, and determine if both the plots describe the data similarly.

# %%
t=sns.load_dataset('penguins')
t
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.violinplot(x='flipper_length_mm', y='sex', hue='sex', data=t);

# %%
sns.boxenplot(x='flipper_length_mm', y='sex', hue='sex', data=t);

# %% [markdown]
# **Problem-6**<br>
# Construct a scatterplot for body mass vs flipper length. Classify the data points based on the type of its species. (use hue)

# %%
sns.scatterplot(x='body_mass_g', y='flipper_length_mm', hue='species', data=t);
